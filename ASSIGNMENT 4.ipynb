# %% [markdown]
# # question 1

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import re

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
name=[]
name_tags=driver.find_elements(By.XPATH,'//table[3][@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]/a')
for i in name_tags:
    name.append(i.text)
art=[]
art_tags=driver.find_elements(By.XPATH,'//table[3][@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')
for i in art_tags:
    art.append(i.text)
date=[]
date_tags=driver.find_elements(By.XPATH,'//table[3][@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')
for i in  date_tags:
    date.append(i.text)
view=[]
view_tags=driver.find_elements(By.XPATH,'//table[3][@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')
for i in view_tags:
    view.append(i.text)
df=pd.DataFrame({'name':name,"artist":art,'date of uplode':date,"views":view})
df
# Out:
#                          name                                       artist  \
# 0            Baby Shark Dance  Pinkfong Baby Shark - Kids' Songs & Stories
# 1                   Despacito                                   Luis Fonsi
# 2               See You Again                                  Wiz Khalifa
# 3               Gangnam Style                                          Psy
# 4                        Baby                                Justin Bieber
# 5                 Bad Romance                                    Lady Gaga
# 6       Charlie Bit My Finger                                        HDCYT
# 7          Evolution of Dance                               Judson Laipply
# 8                  Girlfriend                                  RCA Records
# 9          Evolution of Dance                               Judson Laipply
# 10    Music Is My Hot Hot Sex                               CLARUSBARTEL72
# ...

# %% [markdown]
# # QUESTION 2

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get('https://www.bcci.tv/')

# %%
inte=driver.find_element(By.XPATH,'//li[@class="nav-item"]/a')
inte.click()
time.sleep(3)
title=[]
title_tags=driver.find_elements(By.XPATH,'//div[@class="fix-place ng-binding ng-scope"]/span[1]')
for i in title_tags:
    title.append(i.text)
place=[]
place_tags=driver.find_elements(By.XPATH,'//div[@class="fix-place ng-binding ng-scope"]/span[2]')
for i in place_tags:
    place.append(i.text)
ser=[]
ser_tags=driver.find_elements(By.XPATH,'//h5[2][@class="fix-text"]/span')
for i in ser_tags:
    ser.append(i.text)
date=[]
date_tags=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
for i in date_tags:
    date.append(i.text)
timee=[]
time_tags=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
for i in time_tags:
    timee.append(i.text)
df=pd.DataFrame({"title":title,"series":ser,"date":date,"palce":place,"time":timee})
df
# Out:
#         title                                          series         date  \
# 0  2nd T20I -  INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19  29 DEC 2022
# 1  3rd T20I -  INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19  31 DEC 2022
# 2  4th T20I -  INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19   2 JAN 2023
# 3  1st T20I -      SRI LANKA TOUR OF INDIA T20 SERIES 2022-23   3 JAN 2023
# 4  5th T20I -  INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19   4 JAN 2023
# 5  2nd T20I -      SRI LANKA TOUR OF INDIA T20 SERIES 2022-23   5 JAN 2023
# 6  3rd T20I -      SRI LANKA TOUR OF INDIA T20 SERIES 2022-23   7 JAN 2023
# 7   1st ODI -      SRI LANKA TOUR OF INDIA ODI SERIES 2022-23  10 JAN 2023
#
#                                       palce         time
# 0                 Steyn City School Ground,  5:15 PM IST
# 1                 Steyn City School Ground,  1:30 PM IST
# 2                 Steyn City School Ground,  5:15 PM IST
# 3                         Wankhede Stadium,  7:00 PM IST
# ...

# %% [markdown]
# # QUESTION 3

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')
import re

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get('https://www.guru99.com/')

# %%
driver.maximize_window()
time.sleep(6)
sel=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a')
sel.click()
time.sleep(5)
tut=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a')
tut.click()
time.sleep(3)
name=[]
name_tags=driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]/p/strong')
for i in name_tags:
    name.append(i.text)
namee=name[0:41]
k2=[]
for i in range(len(namee)):
    x1=re.findall(r'. (.*):',namee[i])
    k2.append(x1)    
des=[]
des_tags=driver.find_elements(By.XPATH,'//div[@class="entry-content-wrap"]/div/p')
for i in des_tags:
    des.append(i.text)
dess=des[0:41]
k=[]
for i in range(len(dess)):
    X=re.findall(r':(.*)',dess[i])
    k.append(X)
df=pd.DataFrame({'name':k2,'description':k})
df
# Out:
#                                      name  \
# 0            [ElementNotVisibleException]
# 1         [ElementNotSelectableException]
# 2                [NoSuchElementException]
# 3                  [NoSuchFrameException]
# 4               [NoAlertPresentException]
# 5                 [NoSuchWindowException]
# 6        [StaleElementReferenceException]
# 7              [SessionNotFoundException]
# 8                      [TimeoutException]
# 9                    [WebDriverException]
# 10            [ConnectionClosedException]
# 11     [ElementClickInterceptedException]
# 12      [ElementNotInteractableException]
# 13             [ErrorInResponseException]
# 14  [ErrorHandler.UnknownServerException]
# 15         [ImeActivationFailedException]
# 16             [ImeNotAvailableException]
# 17         [InsecureCertificateException]
# 18             [InvalidArgumentException]
# 19         [InvalidCookieDomainException]
# 20          [InvalidCoordinatesException]
# ...

# %% [markdown]
# # QUESTION 4

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get("https://www.statisticstimes.com/")

# %%
cli=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
cli.click()
time.sleep(2)
ind=driver.find_element(By.XPATH,'//div[@class="navbar"]/div[2]/div/a[3]')
ind.click()
time.sleep(2)
driver.back()
cli=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
cli.click()
time.sleep(2)
ind=driver.find_element(By.XPATH,'//div[@class="navbar"]/div[2]/div/a[3]')
ind.click()
time.sleep(2)
stg=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
stg.click()
time.sleep(4)
state=[]
state_tags=driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[2]')
for i in state_tags:
    state.append(i.text)
gds18=[]
gds_tags18=driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[3]')
for i in gds_tags18:
    gds18.append(i.text)
gds19=[]
gds_tags19=driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[4]')
for i in gds_tags19:
    gds19.append(i.text)
share18=[]
share_tags18=driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[5]')
for i in share_tags18:
    share18.append(i.text)
b=[]
b_tags=driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[6]')
for i in b_tags:
    b.append(i.text)
rank=[]
rank_tags=driver.find_elements(By.XPATH,'//div[@class="dataTables_wrapper"]/table/tbody/tr/td[1]')
for i in rank_tags:
    rank.append(i.text)
df=pd.DataFrame({"rank":rank,"state":state,"gsdp(18-19)":gds18,"gsdp(19-20)":gds19,"share":share18,"gdp":b})
df
# Out:
#    rank                      state gsdp(18-19) gsdp(19-20)   share      gdp
# 0     1                Maharashtra           -   2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu   1,845,853   1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh   1,687,818   1,584,764   8.39%  240.726
# 3     4                    Gujarat           -   1,502,899   7.96%  228.290
# 4     5                  Karnataka   1,631,977   1,493,127   7.91%  226.806
# ..  ...                        ...         ...         ...     ...      ...
# 61   29                     Sikkim      28,391      25,141   0.15%   17,060
# 62   30                   Nagaland           -      24,534   0.15%        -
# 63   31          Arunachal Pradesh           -      22,488   0.13%        -
# 64   32                    Mizoram      24,424      20,947   0.13%   17,797
# 65   33  Andaman & Nicobar Islands           -           -       -        -
#
# [66 rows x 6 columns]

# %% [markdown]
# # QUESTION 5

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get("https://github.com/")

# %%
sin=driver.find_element(By.XPATH,'//div[@class="position-relative mr-lg-3 d-lg-inline-block"]/a')
sin.click()
time.sleep(3)
emw=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/main/div/div[4]/form/input[2]')
emw.send_keys("*****************")
psw=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/main/div/div[4]/form/div/input[1]')
psw.send_keys("****************")
log=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/main/div/div[4]/form/div/input[11]')
log.click()
time.sleep(3)
exp=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div[3]/nav/a[5]')
exp.click()
time.sleep(3)
tr=driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/main/div[1]/nav/div/a[3]')
tr.click()
time.sleep(5)
title=[]
title_tags=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]/a')
for i in title_tags:
    title.append(i.text)
dis=[]
dis_tags=driver.find_elements(By.XPATH,'//article[@class="Box-row"]/p')
for i in dis_tags:
    dis.append(i.text)
dis.insert(1,"nil")
dis.insert(4,"nil")
lan=[]
lan_tags=driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]/span[2]')
for i in lan_tags:
    lan.append(i.text)
lan.insert(16,"nil")
lan.insert(6,"nil")
lan.insert(5,"nil")
lan.insert(7,"nil")
df=pd.DataFrame({"title":title,'discription':dis,'language':lan})
df
# Out:
#                                                 title  \
# 0                           LAION-AI / Open-Assistant
# 1                           SunWeb3Sec / DeFiHackLabs
# 2                ChatGPT-Hackers / ChatGPT-API-server
# 3                                     lencx / ChatGPT
# 4                                    skyzh / mini-lsm
# 5                  mouredev / retos-programacion-2023
# 6                                  merbanan / rtl_433
# 7                                     exaloop / codon
# 8                                 acheong08 / ChatGPT
# 9                              HavocFramework / Havoc
# 10                             sindresorhus / awesome
# 11                   dreamncn / ParallelsDesktopCrack
# 12                                      novuhq / novu
# 13                   trekhleb / javascript-algorithms
# 14                 codecrafters-io / build-your-own-x
# 15                 donnemartin / system-design-primer
# ...

# %%
#due to confidential information the password and login details hiden

# %% [markdown]
# # QUESTION 6

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get("https://www.billboard.com/")

# %%
chart=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
chart.click()
driver.execute_script("window.scrollBy(0,670)")
time.sleep(5)
ful=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
ful.click()
time.sleep(4)
song=[]
song_tags=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/h3')
for i in song_tags:
    song.append(i.text)
art=[]
art_tags=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[1]/span')
for i in art_tags:
    art.append(i.text)
lw=[]
lw_tags=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[4]/span')
for i in lw_tags:
    lw.append(i.text)
pr=[]
pr_tags=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[5]/span')
for i in pr_tags:
    pr.append(i.text)
wc=[]
wc_tags=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[6]/span')
for i in wc_tags:
    wc.append(i.text)
df=pd.DataFrame({"song":song,"artist":art,"last weak":lw,"peak position":pr,"weak on chart":wc})
df
# Out:
#                                  song                       artist last weak  \
# 0     All I Want For Christmas Is You                 Mariah Carey         1
# 1   Rockin' Around The Christmas Tree                   Brenda Lee         2
# 2                    Jingle Bell Rock                  Bobby Helms         4
# 3             A Holly Jolly Christmas                    Burl Ives         5
# 4                      Last Christmas                        Wham!         6
# ..                                ...                          ...       ...
# 95                          Down Home                 Jimmie Allen         -
# 96                One Thing At A Time                Morgan Wallen        81
# 97                     Hold Me Closer  Elton John & Britney Spears        89
# 98                                Far                          SZA        61
# 99                           All Mine                 Brent Faiyaz        95
#
#    peak position weak on chart
# ...

# %% [markdown]
# # QUESTION 7

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get('https://www.naukri.com/hr-recruiters-consultants')

# %%
tab=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')
tab.send_keys("data science")
sec=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button')
sec.click()
time.sleep(4)
name=[]
name_tags=driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
for i in name_tags:
    name.append(i.text)
dis=[]
dis_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
for i in dis_tags:
    dis.append(i.text)
com=[]
com_tags=driver.find_elements(By.XPATH,'//p[@class="highlightable"]/a[2]')
for i in com_tags:
    com.append(i.text)
skill=[]
skill_tags=driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
for i in skill_tags:
    skill.append(i.text)
loc=[]
loc_tags=driver.find_elements(By.XPATH,'//p[@class="highlightable"]/span[2]')
for i in loc_tags:
    loc.append(i.text)
loc.insert(16,"nil")
loc.insert(49,"nil")
df=pd.DataFrame({"name":name,"designation":dis,"company":com,"skill":skill,"location":loc})
df
# Out:
#                                              name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                             Vaishnavi Kudalkar
# 15                                 Priyanka Akiri
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %% [markdown]
# # QUESTION 8

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
name=[]
name_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in name_tags:
    name.append(i.text)
an=[]
an_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in an_tags:
    an.append(i.text)
vol=[]
vol_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in vol_tags:
    vol.append(i.text)
pub=[]
pub_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in pub_tags:
    pub.append(i.text)
gen=[]
gen_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in gen_tags:
    gen.append(i.text)
df=pd.DataFrame({"name":name,"author name":an,"volume":vol,"publisher":pub,"genre":gen})
df
# Out:
#                                                  name       author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#        volume        publisher                        genre
# ...

# %% [markdown]
# # QUESTION 9

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import warnings
warnings.filterwebdriver('ignore')
import time

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
name=[]
name_tags=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/h3/a')
for i in name_tags:
    name.append(i.text)
year=[]
year_tags=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/h3/span[2]')
for i in year_tags:
    year.append(i.text)
gen=[]
gen_tags=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p/span[5]')
for i in gen_tags:
    gen.append(i.text)
run=[]
run_tags=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p/span[3]')
for i in run_tags:
    run.append(i.text)
rat=[]
rat_tags=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/div/div/span[2]')
for i in rat_tags:
    rat.append(i.text)
vot=[]
vot_tags=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[4]/span[2]')
for i in vot_tags:
    vot.append(i.text)
df=pd.DataFrame({"name":name,"year":year,"genre":gen,"run-time":run,"rating":rat,"vote":vot})
df
# Out:
#                               name         year                     genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    run-time rating       vote
# 0    57 min    9.2  2,098,010
# ...

# %% [markdown]
# # QUESTION 10

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome(r'E:\chromedriver_win32 (2).exe')
driver.get("https://archive.ics.uci.edu/ml/index.php")

# %%
cli=driver.find_element(By.XPATH,'//span[2][@class="whitetext"]/a[1]')
cli.click()
time.sleep(4)
name=[]
name_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]/b/a')
for i in name_tags:
    name.append(i.text)
data=[]
data_tags=driver.find_elements(By.XPATH,'//table[@cellpadding="5"]/tbody/tr/td[2]/p')
for i in data_tags:
    data.append(i.text)
del data[0]
task=[]
task_tags=driver.find_elements(By.XPATH,'//table[@cellpadding="5"]/tbody/tr/td[3]/p')
for i in task_tags:
    task.append(i.text)
del task[0]
del task[622]
at=[]
at_tags=driver.find_elements(By.XPATH,'//table[@cellpadding="5"]/tbody/tr/td[4]/p')
for i in at_tags:
    at.append(i.text)
del at[0]
ints=[]
i_tags=driver.find_elements(By.XPATH,'//table[@cellpadding="5"]/tbody/tr/td[5]/p')
for i in i_tags:
    ints.append(i.text)
del ints[0]
a=[]
a_tags=driver.find_elements(By.XPATH,'//table[@cellpadding="5"]/tbody/tr/td[6]/p')
for i in a_tags:
    a.append(i.text)
del a[0]
year=[]
year_tags=driver.find_elements(By.XPATH,'//table[@cellpadding="5"]/tbody/tr/td[7]/p')
for i in year_tags:
    year.append(i.text)
del year[0]
df=pd.DataFrame({"data name":name,"data type":data,"task":task,"attribute type":at,"no of instance":ints,"no of attribute":a,"year":year})
df
# Out:
#                                              data name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       data type                  task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
